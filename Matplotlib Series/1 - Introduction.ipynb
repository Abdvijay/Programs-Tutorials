# %%
import matplotlib as mpl

print(mpl.__version__)
# Out:
# 3.8.3

# %%
import matplotlib.pyplot as plt
import numpy as np

years = np.array([2021, 2022, 2023, 2024, 2025, 2026])
subs = np.array([0, 10000, 60000, 100000, 200000, 300000])

plt.plot(years, subs)
plt.show()

# %%
# If we didn't provide some axis

plt.plot(subs)
