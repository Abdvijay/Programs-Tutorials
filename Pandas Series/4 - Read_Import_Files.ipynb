# %%
import pandas as pd

df = pd.read_csv("customers-100.csv")
print(df)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
# Printing first 5 data in dataframe only specified columns
print(df[["Customer Id","City","Country"]].head())
# Out:
#        Customer Id               City                     Country
# 0  DD37Cf93aecA6Dc       East Leonard                       Chile
# 1  1Ef7b82A4CAAD10  East Jimmychester                    Djibouti
# 2  6F94879bDAfE5a6      Isabelborough         Antigua and Barbuda
# 3  5Cef8BFA16c5e3c         Bensonview          Dominican Republic
# 4  053d585Ab6b3159     West Priscilla  Slovakia (Slovak Republic)

# %%
# Printing last 5 data in dataframe
print(df[["Customer Id", "Company", "City", "Country"]].tail())
# Out:
#         Customer Id                Company             City          Country
# 95  cb8E23e48d22Eae              Carey LLC     East Richard           Guyana
# 96  CeD220bdAaCfaDf  Ware, Burns and Oneal     New Bradview        Sri Lanka
# 97  28CDbC0dFe4b1Db          Schmitt-Jones       Ortegaland  Solomon Islands
# 98  c23d1D9EE8DEB0A     Fitzgerald-Harrell  Lake Elijahview            Aruba
# 99  2354a0E336A91A1     Le, Nash and Cross        Judymouth         Honduras

# %%
# Printing all data using to_string method
# Dont try this for large dataset

print(df.head().to_string())
# Out:
#    Index      Customer Id First Name Last Name                          Company               City                     Country                 Phone 1                Phone 2                        Email Subscription Date                      Website
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter                  Rasmussen Group       East Leonard                       Chile            229.077.5154       397.884.0519x718     zunigavanessa@smith.info        2020-08-24   http://www.stephenson.com/
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano                      Vega-Gentry  East Jimmychester                    Djibouti              5153435776       686-620-1820x944              vmata@colon.com        2021-04-23        http://www.hobbs.com/
# ...

# %%
json_df = pd.read_json("iris.json")
# print(json_df)
# print(json_df.shape)
# print(json_df.tail())
# print(json_df.head())
print(json_df)
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            5.1         3.5          1.4         0.2     setosa
# 2            5.1         3.5          1.4         0.2     setosa
# 3            5.1         3.5          1.4         0.2     setosa
# 4            5.1         3.5          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 150          6.7         3.0          5.2         2.3  virginica
# 151          6.3         2.5          5.0         1.9  virginica
# 152          6.5         3.0          5.2         2.0  virginica
# 153          6.2         3.4          5.4         2.3  virginica
# 154          5.9         3.0          5.1         1.8  virginica
#
# [155 rows x 5 columns]

# %%
# Exporting

df.to_excel('iris.xlsx') # to excel format
df.to_csv('iris.csv') # to csv format
