# %%
# Pandas is nothing but its an Python library

# Built on using by NumPy

# Pandas means -> Panal Data = Pandas

# It contains Series/Dataframes

# 1. Series -> 1D array -> It contains only 1 row data, 1 column datas.

# 2. Dataframes -> Table format data (Excelsheet, Spreadsheets, etc).

# Pandas are mostly used for storing, manipulation, import and export, etc.

# %%
# Checking pandas version

import pandas as pd

print(pd.__version__)
# Out:
# 2.2.1
